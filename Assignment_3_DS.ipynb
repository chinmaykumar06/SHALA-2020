# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmaykumar06/SHALA-2020/blob/master/Assignment_3_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd 'drive'
# Out:
# /content/drive

# %%
# %cd 'My Drive'
# Out:
# /content/drive/My Drive

# %%
# %cd 'Colab Notebooks'
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.tail(10)
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
# Draw the heatmap 
corr_values = movies.corr()
plt.figure(figsize = (15,10))
sns.heatmap(corr_values, vmin = -1, cmap="coolwarm", annot=True)
plt.show()

# %%
# Creating a mask for removing duplicates 
mask = np.zeros_like(movies.corr(), dtype=np.bool) # create matrix of 0's of the given matrix size
mask[np.triu_indices_from(mask)] = True # changing the upper triangle matrix element to True (1),for masking it
plt.figure(figsize = (15,10))
sns.heatmap(corr_values, vmin = -1, cmap="coolwarm", annot=True, mask=mask)
plt.show()

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
train.hist(figsize=(20,20))

# Find out the redundant features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f611b8978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f61153be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f61204668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60eae390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60def0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60e24320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60dd5588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60d8a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60d8a828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60cf3cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60d27f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60ce71d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60c9a438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60c506a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60c03908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60bb59b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60bebd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60ba90f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60b5a470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60b0e7f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60abfb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60a72ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60a2f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60a62630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60a129b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f609c6d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f609850f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f60937470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6096b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2f6091bb70>]],
#       dtype=object)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
sns.regplot(x=movies["imdb_rating"], y=movies["audience_score"])

# %%
# Change marker of the scatter plot
sns.regplot(x=movies["imdb_rating"], y=movies["audience_score"], scatter_kws={"color":"red","alpha":0.3,"s":200})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x="petal_length", y="petal_width", data=df, 
           fit_reg=False, hue='species', legend=False, 
           scatter_kws={"s":100})
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
from pylab import *
# library and dataset 
df = sns.load_dataset('iris')
subplot(2,2,1)
# density plot with shade
sns.kdeplot(df['sepal_width'], shade=True, color='r')

subplot(2,2,2)
# density plot with shade
sns.kdeplot(df['sepal_length'], shade=True, color='b')

subplot(2,2,3)
# density plot with shade
sns.kdeplot(df['petal_width'], shade=True, color='g')

subplot(2,2,4)
# density plot with shade
sns.kdeplot(df['petal_length'], shade=True, color='y')

# %%
subplot(2,2,1)
# density plot with shade
sns.kdeplot(df['sepal_width'], shade=True, color='r', cumulative=True)

subplot(2,2,2)
# density plot with shade
sns.kdeplot(df['sepal_length'], shade=True, color='b', cumulative=True)

subplot(2,2,3)
# density plot with shade
sns.kdeplot(df['petal_width'], shade=True, color='g', cumulative=True)

subplot(2,2,4)
# density plot with shade
sns.kdeplot(df['petal_length'], shade=True, color='y', cumulative=True)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
sns.violinplot( x=df["species"], y=df["sepal_length"], palette="Blues")

# %%
# Change the color of each group 
# Make a dictionary with one specific color per group:
my_pal = {"versicolor": "g", "setosa": "b", "virginica":"m"}
 
#plot it
sns.violinplot( x=df["species"], y=df["sepal_length"], palette=my_pal)
